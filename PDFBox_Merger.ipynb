# %%
import pandas as pd

# %%
PDFBox_v26 = pd.read_csv("/content/PDFBox_MR/pdfBox-2.0.26.csv", header=1)
display(PDFBox_v26)
# Out:
#                                                   Class   CBO  DIT  LCOM  NOC  \
# 0                        org.apache.fontbox.EncodedFont   NaN  NaN   NaN  NaN
# 1                        org.apache.fontbox.FontBoxFont   NaN  NaN   NaN  NaN
# 2                      org.apache.fontbox.afm.AFMParser  12.0  1.0   1.0  0.0
# 3                  org.apache.fontbox.afm.AFMParserTest   2.0  1.0   1.0  0.0
# 4                     org.apache.fontbox.afm.CharMetric   6.0  1.0  14.0  0.0
# ...                                                 ...   ...  ...   ...  ...
# 1492          org.apache.xmpbox.xml.PdfaExtensionHelper  22.0  1.0   2.0  0.0
# 1493          org.apache.xmpbox.xml.XmpParsingException   9.0  3.0   1.0  0.0
# 1494  org.apache.xmpbox.xml.XmpParsingException.Erro...   7.0  NaN   2.0  NaN
# 1495    org.apache.xmpbox.xml.XmpSerializationException   1.0  3.0   0.0  0.0
# 1496                org.apache.xmpbox.xml.XmpSerializer  15.0  1.0   1.0  0.0
#
#       RFC   WMC
# ...

# %%
print(PDFBox_v26.isna().sum())
# Out:
# Class     0
# CBO      49
# DIT      88
# LCOM     49
# NOC      88
# RFC       0
# WMC      49
# dtype: int64

# %%
PDFBox_v26_clean = PDFBox_v26.dropna(how='any', ignore_index='True')
PDFBox_v26_clean['Version'] = '2.0.26'
display(PDFBox_v26_clean)
# Out:
# <ipython-input-4-446ac7647f8b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PDFBox_v26_clean['Version'] = '2.0.26'
#                                                   Class   CBO  DIT  LCOM  NOC  \
# 0                      org.apache.fontbox.afm.AFMParser  12.0  1.0   1.0  0.0
# 1                  org.apache.fontbox.afm.AFMParserTest   2.0  1.0   1.0  0.0
# 2                     org.apache.fontbox.afm.CharMetric   6.0  1.0  14.0  0.0
# 3                      org.apache.fontbox.afm.Composite   3.0  1.0   2.0  0.0
# 4                  org.apache.fontbox.afm.CompositePart   2.0  1.0   3.0  0.0
# ...                                                 ...   ...  ...   ...  ...
# ...

# %%
PDFBox_v27 = pd.read_csv("/content/PDFBox_MR/pdfBox-2.0.27.csv", header=1)
display(PDFBox_v27)
# Out:
#                                                   Class   CBO  DIT  LCOM  NOC  \
# 0                        org.apache.fontbox.EncodedFont   NaN  NaN   NaN  NaN
# 1                        org.apache.fontbox.FontBoxFont   NaN  NaN   NaN  NaN
# 2                      org.apache.fontbox.afm.AFMParser  12.0  1.0   1.0  0.0
# 3                  org.apache.fontbox.afm.AFMParserTest   2.0  1.0   1.0  0.0
# 4                     org.apache.fontbox.afm.CharMetric   6.0  1.0  14.0  0.0
# ...                                                 ...   ...  ...   ...  ...
# 1495          org.apache.xmpbox.xml.PdfaExtensionHelper  22.0  1.0   2.0  0.0
# 1496          org.apache.xmpbox.xml.XmpParsingException   9.0  3.0   1.0  0.0
# 1497  org.apache.xmpbox.xml.XmpParsingException.Erro...   7.0  NaN   2.0  NaN
# 1498    org.apache.xmpbox.xml.XmpSerializationException   1.0  3.0   0.0  0.0
# 1499                org.apache.xmpbox.xml.XmpSerializer  15.0  1.0   1.0  0.0
#
#       RFC   WMC
# ...

# %%
print(PDFBox_v27.isna().sum())
# Out:
# Class     0
# CBO      49
# DIT      88
# LCOM     49
# NOC      88
# RFC       0
# WMC      49
# dtype: int64

# %%
PDFBox_v27_clean = PDFBox_v27.dropna(how='any', ignore_index='True')
PDFBox_v27_clean['Version'] = '2.0.27'
display(PDFBox_v27_clean)
# Out:
# <ipython-input-18-ffc1246e0a0c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PDFBox_v27_clean['Version'] = '2.0.27'
#                                                   Class   CBO  DIT  LCOM  NOC  \
# 0                      org.apache.fontbox.afm.AFMParser  12.0  1.0   1.0  0.0
# 1                  org.apache.fontbox.afm.AFMParserTest   2.0  1.0   1.0  0.0
# 2                     org.apache.fontbox.afm.CharMetric   6.0  1.0  14.0  0.0
# 3                      org.apache.fontbox.afm.Composite   3.0  1.0   2.0  0.0
# 4                  org.apache.fontbox.afm.CompositePart   2.0  1.0   3.0  0.0
# ...                                                 ...   ...  ...   ...  ...
# ...

# %%
PDFBox_v28 = pd.read_csv("/content/PDFBox_MR/pdfBox-2.0.28.csv", header=1)
display(PDFBox_v28)
# Out:
#                                                   Class   CBO  DIT  LCOM  NOC  \
# 0                        org.apache.fontbox.EncodedFont   NaN  NaN   NaN  NaN
# 1                        org.apache.fontbox.FontBoxFont   NaN  NaN   NaN  NaN
# 2                      org.apache.fontbox.afm.AFMParser  12.0  1.0   1.0  0.0
# 3                  org.apache.fontbox.afm.AFMParserTest   2.0  1.0   1.0  0.0
# 4                     org.apache.fontbox.afm.CharMetric   6.0  1.0  14.0  0.0
# ...                                                 ...   ...  ...   ...  ...
# 1495          org.apache.xmpbox.xml.PdfaExtensionHelper  22.0  1.0   2.0  0.0
# 1496          org.apache.xmpbox.xml.XmpParsingException   9.0  3.0   1.0  0.0
# 1497  org.apache.xmpbox.xml.XmpParsingException.Erro...   7.0  NaN   2.0  NaN
# 1498    org.apache.xmpbox.xml.XmpSerializationException   1.0  3.0   0.0  0.0
# 1499                org.apache.xmpbox.xml.XmpSerializer  15.0  1.0   1.0  0.0
#
#       RFC   WMC
# ...

# %%
print(PDFBox_v28.isna().sum())
# Out:
# Class     0
# CBO      49
# DIT      88
# LCOM     49
# NOC      88
# RFC       0
# WMC      49
# dtype: int64

# %%
PDFBox_v28_clean = PDFBox_v28.dropna(how='any', ignore_index='True')
PDFBox_v28_clean['Version'] = '2.0.28'
display(PDFBox_v28_clean)
# Out:
# <ipython-input-19-fa5a220d462b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PDFBox_v28_clean['Version'] = '2.0.28'
#                                                   Class   CBO  DIT  LCOM  NOC  \
# 0                      org.apache.fontbox.afm.AFMParser  12.0  1.0   1.0  0.0
# 1                  org.apache.fontbox.afm.AFMParserTest   2.0  1.0   1.0  0.0
# 2                     org.apache.fontbox.afm.CharMetric   6.0  1.0  14.0  0.0
# 3                      org.apache.fontbox.afm.Composite   3.0  1.0   2.0  0.0
# 4                  org.apache.fontbox.afm.CompositePart   2.0  1.0   3.0  0.0
# ...                                                 ...   ...  ...   ...  ...
# ...

# %%
PDFBox_v29 = pd.read_csv("/content/PDFBox_MR/pdfBox-2.0.29.csv", header=1)
display(PDFBox_v29)
# Out:
#                                                   Class   CBO  DIT  LCOM  NOC  \
# 0                        org.apache.fontbox.EncodedFont   NaN  NaN   NaN  NaN
# 1                        org.apache.fontbox.FontBoxFont   NaN  NaN   NaN  NaN
# 2                      org.apache.fontbox.afm.AFMParser  12.0  1.0   1.0  0.0
# 3                  org.apache.fontbox.afm.AFMParserTest   2.0  1.0   1.0  0.0
# 4                     org.apache.fontbox.afm.CharMetric   6.0  1.0  14.0  0.0
# ...                                                 ...   ...  ...   ...  ...
# 1498          org.apache.xmpbox.xml.PdfaExtensionHelper  22.0  1.0   2.0  0.0
# 1499          org.apache.xmpbox.xml.XmpParsingException   9.0  3.0   1.0  0.0
# 1500  org.apache.xmpbox.xml.XmpParsingException.Erro...   7.0  NaN   2.0  NaN
# 1501    org.apache.xmpbox.xml.XmpSerializationException   1.0  3.0   0.0  0.0
# 1502                org.apache.xmpbox.xml.XmpSerializer  15.0  1.0   1.0  0.0
#
#       RFC   WMC
# ...

# %%
print(PDFBox_v29.isna().sum())
# Out:
# Class     0
# CBO      49
# DIT      88
# LCOM     49
# NOC      88
# RFC       0
# WMC      49
# dtype: int64

# %%
PDFBox_v29_clean = PDFBox_v29.dropna(how='any', ignore_index='True')
display(PDFBox_v29_clean)
# Out:
#                                                   Class   CBO  DIT  LCOM  NOC  \
# 0                      org.apache.fontbox.afm.AFMParser  12.0  1.0   1.0  0.0
# 1                  org.apache.fontbox.afm.AFMParserTest   2.0  1.0   1.0  0.0
# 2                     org.apache.fontbox.afm.CharMetric   6.0  1.0  14.0  0.0
# 3                      org.apache.fontbox.afm.Composite   3.0  1.0   2.0  0.0
# 4                  org.apache.fontbox.afm.CompositePart   2.0  1.0   3.0  0.0
# ...                                                 ...   ...  ...   ...  ...
# 1410  org.apache.xmpbox.xml.DomXmpParser.NamespaceFi...   1.0  1.0   1.0  0.0
# 1411          org.apache.xmpbox.xml.PdfaExtensionHelper  22.0  1.0   2.0  0.0
# 1412          org.apache.xmpbox.xml.XmpParsingException   9.0  3.0   1.0  0.0
# 1413    org.apache.xmpbox.xml.XmpSerializationException   1.0  3.0   0.0  0.0
# 1414                org.apache.xmpbox.xml.XmpSerializer  15.0  1.0   1.0  0.0
#
#       RFC   WMC
# ...

# %%
PDFBox_v30 = pd.read_csv("/content/PDFBox_MR/pdfBox-2.0.30.csv", header=1)
display(PDFBox_v30)
# Out:
#                                                   Class   CBO  DIT  LCOM  NOC  \
# 0                        org.apache.fontbox.EncodedFont   NaN  NaN   NaN  NaN
# 1                        org.apache.fontbox.FontBoxFont   NaN  NaN   NaN  NaN
# 2                      org.apache.fontbox.afm.AFMParser  12.0  1.0   1.0  0.0
# 3                  org.apache.fontbox.afm.AFMParserTest   2.0  1.0   1.0  0.0
# 4                     org.apache.fontbox.afm.CharMetric   6.0  1.0  14.0  0.0
# ...                                                 ...   ...  ...   ...  ...
# 1498          org.apache.xmpbox.xml.PdfaExtensionHelper  22.0  1.0   2.0  0.0
# 1499          org.apache.xmpbox.xml.XmpParsingException   9.0  3.0   1.0  0.0
# 1500  org.apache.xmpbox.xml.XmpParsingException.Erro...   7.0  NaN   2.0  NaN
# 1501    org.apache.xmpbox.xml.XmpSerializationException   1.0  3.0   0.0  0.0
# 1502                org.apache.xmpbox.xml.XmpSerializer  15.0  1.0   1.0  0.0
#
#       RFC   WMC
# ...

# %%
print(PDFBox_v30.isna().sum())
# Out:
# Class     0
# CBO      49
# DIT      88
# LCOM     49
# NOC      88
# RFC       0
# WMC      49
# dtype: int64

# %%
PDFBox_v30_clean = PDFBox_v30.dropna(how='any', ignore_index='True')
PDFBox_v30_clean['Version'] = '2.0.30'
display(PDFBox_v30_clean)
# Out:
# <ipython-input-21-86d90a3a719a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PDFBox_v30_clean['Version'] = '2.0.30'
#                                                   Class   CBO  DIT  LCOM  NOC  \
# 0                      org.apache.fontbox.afm.AFMParser  12.0  1.0   1.0  0.0
# 1                  org.apache.fontbox.afm.AFMParserTest   2.0  1.0   1.0  0.0
# 2                     org.apache.fontbox.afm.CharMetric   6.0  1.0  14.0  0.0
# 3                      org.apache.fontbox.afm.Composite   3.0  1.0   2.0  0.0
# 4                  org.apache.fontbox.afm.CompositePart   2.0  1.0   3.0  0.0
# ...                                                 ...   ...  ...   ...  ...
# ...

# %%
# Create a list of your DataFrames
dfs = [PDFBox_v26_clean, PDFBox_v27_clean, PDFBox_v28_clean, PDFBox_v29_clean, PDFBox_v30_clean]

# Merge the DataFrames
merged_PDFBox_v26_thru_v30 = pd.concat(dfs, ignore_index=True)

display(merged_PDFBox_v26_thru_v30)
# Out:
#                                                   Class   CBO  DIT  LCOM  NOC  \
# 0                      org.apache.fontbox.afm.AFMParser  12.0  1.0   1.0  0.0
# 1                  org.apache.fontbox.afm.AFMParserTest   2.0  1.0   1.0  0.0
# 2                     org.apache.fontbox.afm.CharMetric   6.0  1.0  14.0  0.0
# 3                      org.apache.fontbox.afm.Composite   3.0  1.0   2.0  0.0
# 4                  org.apache.fontbox.afm.CompositePart   2.0  1.0   3.0  0.0
# ...                                                 ...   ...  ...   ...  ...
# 7058  org.apache.xmpbox.xml.DomXmpParser.NamespaceFi...   1.0  1.0   1.0  0.0
# 7059          org.apache.xmpbox.xml.PdfaExtensionHelper  22.0  1.0   2.0  0.0
# 7060          org.apache.xmpbox.xml.XmpParsingException   9.0  3.0   1.0  0.0
# 7061    org.apache.xmpbox.xml.XmpSerializationException   1.0  3.0   0.0  0.0
# 7062                org.apache.xmpbox.xml.XmpSerializer  15.0  1.0   1.0  0.0
#
#       RFC   WMC Version
# ...

# %%
merged_PDFBox_v26_thru_v30_predictors = merged_PDFBox_v26_thru_v30.drop(['CBO', 'NOC'],axis=1)
display(merged_PDFBox_v26_thru_v30_predictors)
# Out:
#                                                   Class  DIT  LCOM  RFC   WMC  \
# 0                      org.apache.fontbox.afm.AFMParser  1.0   1.0  108  99.0
# 1                  org.apache.fontbox.afm.AFMParserTest  1.0   1.0    7   1.0
# 2                     org.apache.fontbox.afm.CharMetric  1.0  14.0   31  29.0
# 3                      org.apache.fontbox.afm.Composite  1.0   2.0    7   5.0
# 4                  org.apache.fontbox.afm.CompositePart  1.0   3.0    6   6.0
# ...                                                 ...  ...   ...  ...   ...
# 7058  org.apache.xmpbox.xml.DomXmpParser.NamespaceFi...  1.0   1.0   16   7.0
# 7059          org.apache.xmpbox.xml.PdfaExtensionHelper  1.0   2.0   66  44.0
# 7060          org.apache.xmpbox.xml.XmpParsingException  3.0   1.0    5   3.0
# 7061    org.apache.xmpbox.xml.XmpSerializationException  3.0   0.0    4   2.0
# 7062                org.apache.xmpbox.xml.XmpSerializer  1.0   1.0   54  27.0
#
#      Version
# 0     2.0.26
# ...

# %%
merged_PDFBox_v26_thru_v30_predictors.to_csv("/content/PDFBox_MR/v26-30_predictors.csv")

# %%
import pandas as pd

# Define the mapping function
def map_class(class_name):
    # Split the class name by periods
    parts = class_name.split('.')

    # Get the last part of the class name
    file_name = parts[-1] + '.java'

    return file_name

# Apply the mapping function to the 'Class' column
merged_PDFBox_v26_thru_v30_predictors['Class'] = merged_PDFBox_v26_thru_v30_predictors['Class'].apply(map_class)

# Display the DataFrame after mutation
display(merged_PDFBox_v26_thru_v30_predictors)
# Out:
#                                Class  DIT  LCOM  RFC   WMC Version
# 0                     AFMParser.java  1.0   1.0  108  99.0  2.0.26
# 1                 AFMParserTest.java  1.0   1.0    7   1.0  2.0.26
# 2                    CharMetric.java  1.0  14.0   31  29.0  2.0.26
# 3                     Composite.java  1.0   2.0    7   5.0  2.0.26
# 4                 CompositePart.java  1.0   3.0    6   6.0  2.0.26
# ...                              ...  ...   ...  ...   ...     ...
# 7058            NamespaceFinder.java  1.0   1.0   16   7.0  2.0.30
# 7059        PdfaExtensionHelper.java  1.0   2.0   66  44.0  2.0.30
# 7060        XmpParsingException.java  3.0   1.0    5   3.0  2.0.30
# 7061  XmpSerializationException.java  3.0   0.0    4   2.0  2.0.30
# 7062              XmpSerializer.java  1.0   1.0   54  27.0  2.0.30
#
# [7063 rows x 6 columns]

# %%
merged_PDFBox_v26_thru_v30_predictors.to_csv("/content/PDFBox_MR/v26-30_predictors-2.csv")

# %% [markdown]
# ###**Processing**

# %%
import json

# %%
with open('/content/Compute_PDFBox/PDFBox_2.0.26_compute.json', 'r') as file:
    data = json.load(file)

print(data)
# Convert dictionary to Pandas DataFrame
Box_v26 = pd.DataFrame(data.items(), columns=['Class', 'Bugs'])
display(Box_v26)
# Out:
# {'CFFParser.java': 5, 'COSParser.java': 11, 'GlyfCompositeDescript.java': 2, 'CFFCharset.java': 0, 'COSWriter.java': 1, 'AcroFormOrphanWidgetsProcessor.java': 5, 'BaseParser.java': 5, 'PDCIDFontType2.java': 2, 'PDFileAttachmentAppearanceHandler.java': 1, 'PageDrawer.java': 3, 'COSFilterInputStream.java': 1, 'PDAnnotationMarkup.java': 0, 'CreateSignature.java': 2, 'CreateVisibleSignature.java': 3, 'CreateVisibleSignature2.java': 2, 'TestToUnicodeWriter.java': 2, 'PfbParserTest.java': 3, 'PfbParser.java': 1, 'TestTextToPdf.java': 4, 'TextToPDF.java': 2, 'ToUnicodeWriter.java': 1, 'PDImageXObjectTest.java': 1, 'PDImageXObject.java': 1, 'TestImageIOUtils.java': 0, 'PDFCloneUtility.java': 2, 'AddValidationInformation.java': 1, 'PDFieldFactory.java': 0, 'PDFRenderer.java': 3, 'SigUtils.java': 2, 'CRLVerifier.java': 0, 'CertificateVerifier.java': 0, 'OcspHelper.java': 0, 'CertInformationCollector.java': 0, 'ConnectedInputStream.java': 0, 'TestCreateSignature.java': 1, 'TTFParser.java': 1, '
# ...

# %%
with open('/content/Compute_PDFBox/PDFBox_2.0.27_compute.json', 'r') as file:
    data = json.load(file)

# Convert dictionary to Pandas DataFrame
Box_v27 = pd.DataFrame(data.items(), columns=['Class', 'Bugs'])
display(Box_v27)
# Out:
#                              Class  Bugs
# 0                 PDType0Font.java     3
# 1               COSDictionary.java     5
# 2              FontMapperImpl.java     1
# 3           PDDocumentCatalog.java     4
# 4   UnmodifiableCOSDictionary.java     0
# ..                             ...   ...
# 82                PDFRenderer.java     0
# 83         FDFAnnotationCaret.java     0
# 84                   PDStream.java     0
# 85                     Filter.java     0
# 86            PDGraphicsState.java     0
#
# [87 rows x 2 columns]

# %%
with open('/content/Compute_PDFBox/PDFBox_2.0.28_compute.json', 'r') as file:
    data = json.load(file)

# Convert dictionary to Pandas DataFrame
Box_v28 = pd.DataFrame(data.items(), columns=['Class', 'Bugs'])
display(Box_v28)
# Out:
#                                      Class  Bugs
# 0                     PDFStreamParser.java     1
# 1                          BaseParser.java     5
# 2                          PageDrawer.java     3
# 3                           COSParser.java     1
# 4                    PDFMergerUtility.java     4
# 5           AppearanceGeneratorHelper.java     2
# 6                           LZWFilter.java     0
# 7                          OSXAdapter.java     0
# 8                       XMPSchemaTest.java     0
# 9                       GlyphRenderer.java     1
# 10                           BidiTest.java     1
# 11                ContentStreamWriter.java     2
# 12             GlyphSubstitutionTable.java     2
# 13                    Type2CharString.java     0
# 14                        NamingTable.java     1
# 15                       CmapSubtable.java     0
# 16                       TTFSubsetter.java     1
# 17                           PDChoice.java     1
# ...

# %%
with open('/content/Compute_PDFBox/PDFBox_2.0.29_compute.json', 'r') as file:
    data = json.load(file)

# Convert dictionary to Pandas DataFrame
Box_v29 = pd.DataFrame(data.items(), columns=['Class', 'Bugs'])
display(Box_v29)
# Out:
#                                 Class  Bugs
# 0            CertificateVerifier.java     0
# 1          CertInformationHelper.java     0
# 2            PDFXrefStreamParser.java     1
# 3                    Type1Parser.java     1
# 4                   PDEncryption.java     0
# 5                PDFStreamEngine.java     1
# 6             XObjImageValidator.java     1
# 7                 PDTrueTypeFont.java     1
# 8                 PDCIDFontType2.java     4
# 9              InputStreamSource.java     1
# 10               PDFStreamParser.java     2
# 11            RandomAccessSource.java     1
# 12              SequentialSource.java     1
# 13            CreateRadioButtons.java     1
# 14                     PDCIDFont.java     1
# 15                    PageDrawer.java     5
# 16                      SigUtils.java     1
# 17                      PrintPDF.java     0
# 18             OpaquePDFRenderer.java     1
# 19                    ExtractXMP.java     0
# ...

# %%
with open('/content/Compute_PDFBox/PDFBox_2.0.30_compute.json', 'r') as file:
    data = json.load(file)

# Convert dictionary to Pandas DataFrame
Box_v30 = pd.DataFrame(data.items(), columns=['Class', 'Bugs'])
display(Box_v30)
# Out:
#                               Class  Bugs
# 0                  PDType3Font.java     0
# 1             TestCOSIncrement.java     3
# 2                    DCTFilter.java     1
# 3              KerningSubtable.java     1
# 4                   PDPageTree.java     0
# 5                    PDFParser.java     0
# 6                  CMapManager.java     1
# 7                  TilingPaint.java     1
# 8             SecurityProvider.java     0
# 9       FileSystemFontProvider.java     2
# 10                  PDFToImage.java     1
# 11      GlyphSubstitutionTable.java     1
# 12                OpenTypeFont.java     2
# 13             SecurityHandler.java     1
# 14                  SimpleFont.java     0
# 15                   Type0Font.java     0
# 16            XMPSchemaFactory.java     1
# 17             PDFStreamParser.java     1
# 18                PDSimpleFont.java     1
# 19          SampledImageReader.java     1
# 20                     COSName.java     1
# ...

# %%
# Create a list of your DataFrames
dfs = [Box_v26, Box_v27, Box_v28, Box_v29, Box_v30]

# Merge the DataFrames
Box_v26_thru_v30 = pd.concat(dfs, ignore_index=True)

display(Box_v26_thru_v30)
# Out:
#                           Class  Bugs
# 0                CFFParser.java     5
# 1                COSParser.java    11
# 2    GlyfCompositeDescript.java     2
# 3               CFFCharset.java     0
# 4                COSWriter.java     1
# ..                          ...   ...
# 346                PDColor.java     0
# 347             PDDocument.java     1
# 348    MaximumProfileTable.java     0
# 349            PDRectangle.java     0
# 350       PDFMergerUtility.java     1
#
# [351 rows x 2 columns]

# %%
Box_v26_thru_v30.to_csv("/content/PDFBox_MR/v26-30_targets.csv")

# %%
import pandas as pd

# Assuming 'Class' is the key column in both DataFrames

# Perform left join on 'Class' column
result_df = pd.merge(Box_v26_thru_v30, merged_PDFBox_v26_thru_v30_predictors, on='Class', how='inner')

# Display the resulting DataFrame
display(result_df)
# Out:
#                  Class  Bugs  DIT  LCOM  RFC    WMC Version
# 0       CFFParser.java     5  1.0   1.0  126  137.0  2.0.26
# 1       CFFParser.java     5  1.0   1.0  126  138.0  2.0.27
# 2       CFFParser.java     5  1.0   1.0  127  138.0  2.0.28
# 3       CFFParser.java     5  1.0   1.0  127  138.0     NaN
# 4       CFFParser.java     5  1.0   1.0  127  138.0  2.0.30
# ...                ...   ...  ...   ...  ...    ...     ...
# 1738  PDRectangle.java     0  1.0   1.0   45   22.0  2.0.26
# 1739  PDRectangle.java     0  1.0   1.0   45   22.0  2.0.27
# 1740  PDRectangle.java     0  1.0   1.0   45   22.0  2.0.28
# 1741  PDRectangle.java     0  1.0   1.0   45   22.0     NaN
# 1742  PDRectangle.java     0  1.0   1.0   45   22.0  2.0.30
#
# [1743 rows x 7 columns]

# %%
clean_1 = result_df.dropna()
display(clean_1)
# Out:
#                          Class  Bugs  DIT  LCOM  RFC    WMC Version
# 0               CFFParser.java     5  1.0   1.0  126  137.0  2.0.26
# 1               CFFParser.java     5  1.0   1.0  126  138.0  2.0.27
# 2               CFFParser.java     5  1.0   1.0  127  138.0  2.0.28
# 4               CFFParser.java     5  1.0   1.0  127  138.0  2.0.30
# 5               CFFParser.java     1  1.0   1.0  126  137.0  2.0.26
# ...                        ...   ...  ...   ...  ...    ...     ...
# 1737  MaximumProfileTable.java     0  2.0   1.0   35   33.0  2.0.30
# 1738          PDRectangle.java     0  1.0   1.0   45   22.0  2.0.26
# 1739          PDRectangle.java     0  1.0   1.0   45   22.0  2.0.27
# 1740          PDRectangle.java     0  1.0   1.0   45   22.0  2.0.28
# 1742          PDRectangle.java     0  1.0   1.0   45   22.0  2.0.30
#
# [1393 rows x 7 columns]

# %%
clean_2 = clean_1.copy(deep=True)

# Define a function to map values
def bug_flagger(bugs):
    if bugs > 0:
        return 1
    else:
        return 0

# Apply the function to create the 'bug' column
clean_2['bug'] = clean_2['Bugs'].apply(lambda x: bug_flagger(x))

display(clean_2)
# Out:
#                          Class  Bugs  DIT  LCOM  RFC    WMC Version  bug
# 0               CFFParser.java     5  1.0   1.0  126  137.0  2.0.26    1
# 1               CFFParser.java     5  1.0   1.0  126  138.0  2.0.27    1
# 2               CFFParser.java     5  1.0   1.0  127  138.0  2.0.28    1
# 4               CFFParser.java     5  1.0   1.0  127  138.0  2.0.30    1
# 5               CFFParser.java     1  1.0   1.0  126  137.0  2.0.26    1
# ...                        ...   ...  ...   ...  ...    ...     ...  ...
# 1737  MaximumProfileTable.java     0  2.0   1.0   35   33.0  2.0.30    0
# 1738          PDRectangle.java     0  1.0   1.0   45   22.0  2.0.26    0
# 1739          PDRectangle.java     0  1.0   1.0   45   22.0  2.0.27    0
# 1740          PDRectangle.java     0  1.0   1.0   45   22.0  2.0.28    0
# 1742          PDRectangle.java     0  1.0   1.0   45   22.0  2.0.30    0
#
# [1393 rows x 8 columns]

# %%
clean_3 = clean_2.copy(deep=True)
clean_3 = clean_3.drop(['Class', 'Bugs', 'Version'], axis=1)
clean_3['temp'] = 1
display(clean_3)
# Out:
#       DIT  LCOM  RFC    WMC  bug  temp
# 0     1.0   1.0  126  137.0    1     1
# 1     1.0   1.0  126  138.0    1     1
# 2     1.0   1.0  127  138.0    1     1
# 4     1.0   1.0  127  138.0    1     1
# 5     1.0   1.0  126  137.0    1     1
# ...   ...   ...  ...    ...  ...   ...
# 1737  2.0   1.0   35   33.0    0     1
# 1738  1.0   1.0   45   22.0    0     1
# 1739  1.0   1.0   45   22.0    0     1
# 1740  1.0   1.0   45   22.0    0     1
# 1742  1.0   1.0   45   22.0    0     1
#
# [1393 rows x 6 columns]

# %%
PDFBox_v31 = pd.read_csv("/content/PDFBox_MR/pdfBox-2.0.31.csv", header=1)
PDFBox_v31_clean = PDFBox_v31.dropna(how='any', ignore_index='True')
PDFBox_v31_clean['Version'] = '2.0.31'
PDFBox_v31_clean = PDFBox_v31_clean.drop(['CBO', 'NOC'],axis=1)
# Apply the mapping function to the 'Class' column
PDFBox_v31_clean['Class'] = PDFBox_v31_clean['Class'].apply(map_class)
display(PDFBox_v31_clean)
# Out:
# <ipython-input-84-b4869e6c742f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PDFBox_v31_clean['Version'] = '2.0.31'
#                                Class  DIT  LCOM  RFC    WMC Version
# 0                     AFMParser.java  1.0   1.0  108  101.0  2.0.31
# 1                 AFMParserTest.java  1.0   1.0    7    1.0  2.0.31
# 2                    CharMetric.java  1.0  14.0   31   29.0  2.0.31
# 3                     Composite.java  1.0   2.0    7    5.0  2.0.31
# 4                 CompositePart.java  1.0   3.0    6    6.0  2.0.31
# ...                              ...  ...   ...  ...    ...     ...
# 1414            NamespaceFinder.java  1.0   1.0   16    7.0  2.0.31
# ...

# %%
with open('/content/Compute_PDFBox/PDFBox_2.0.31_compute.json', 'r') as file:
    data = json.load(file)

# Convert dictionary to Pandas DataFrame
Box_v31 = pd.DataFrame(data.items(), columns=['Class', 'Bugs'])
display(Box_v31)
# Out:
#                                          Class  Bugs
# 0                        PDDeviceCMYKTest.java     1
# 1                             PDFDebugger.java     1
# 2                               AFMParser.java     1
# 3                        COSArrayListTest.java     0
# 4                          PDCIDFontType2.java     2
# ..                                         ...   ...
# 71                              PfbParser.java     2
# 72                          PfbParserTest.java     1
# 73                 PDOptionalContentGroup.java     2
# 74  PDOptionalContentMembershipDictionary.java     1
# 75                              Type1Font.java     1
#
# [76 rows x 2 columns]

# %%
Box_v31.dtypes
# Out:
# Class    object
# Bugs      int64
# dtype: object

# %%
targets = pd.merge(Box_v31, PDFBox_v31_clean, on='Class', how='inner')
targets = targets.dropna()
# .apply(lambda x: bug_flagger(x)).drop(['Class', 'Bugs', 'Version'], axis=1)
targets['bug'] = targets['Bugs'].apply(lambda x: bug_flagger(x))
targets['temp'] = 0
targets = targets.drop(['Class', 'Bugs', 'Version'], axis=1)
display(targets)
# Out:
#     DIT  LCOM  RFC    WMC  bug  temp
# 0   3.0   2.0   19    2.0    1     0
# 1   6.0   2.0  285  167.0    1     0
# 2   1.0   1.0  108  101.0    1     0
# 3   1.0   1.0   63   19.0    0     0
# 4   2.0   2.0   86   53.0    1     0
# ..  ...   ...  ...    ...  ...   ...
# 70  1.0   2.0   33   27.0    1     0
# 71  1.0   2.0   29    4.0    1     0
# 72  2.0   1.0   17   15.0    1     0
# 73  2.0   1.0   21   12.0    1     0
# 74  1.0  36.0   67   48.0    1     0
#
# [75 rows x 6 columns]

# %% [markdown]
# ###**Model Training.**

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# %%
X_train = clean_3.drop('bug', axis=1)
y_train = clean_3['bug']
X_test = targets.drop("bug", axis=1)
y_test = targets["bug"]

# %%
display(X_train)
display(y_train)
display(X_test)
display(y_test)
# Out:
#       DIT  LCOM  RFC    WMC  temp
# 0     1.0   1.0  126  137.0     1
# 1     1.0   1.0  126  138.0     1
# 2     1.0   1.0  127  138.0     1
# 4     1.0   1.0  127  138.0     1
# 5     1.0   1.0  126  137.0     1
# ...   ...   ...  ...    ...   ...
# 1737  2.0   1.0   35   33.0     1
# 1738  1.0   1.0   45   22.0     1
# 1739  1.0   1.0   45   22.0     1
# 1740  1.0   1.0   45   22.0     1
# 1742  1.0   1.0   45   22.0     1
#
# [1393 rows x 5 columns]
# 0       1
# 1       1
# 2       1
# 4       1
# 5       1
#        ..
# 1737    0
# 1738    0
# 1739    0
# 1740    0
# 1742    0
# Name: bug, Length: 1393, dtype: int64
#     DIT  LCOM  RFC    WMC  temp
# 0   3.0   2.0   19    2.0     0
# 1   6.0   2.0  285  167.0     0
# 2   1.0   1.0  108  101.0     0
# 3   1.0   1.0   63   19.0     0
# 4   2.0   2.0   86   53.0     0
# ..  ...   ...  ...    ...   ...
# 70  1.0   2.0   33   27.0     0
# 71  1.0   2.0   29    4.0     0
# 72  2.0   1.0   17   15.0     0
# ...

# %%
# perform grid search to optimize the tree's depth
param_grid = {"max_depth": range(1, 11)}
decision_tree = DecisionTreeClassifier(random_state=0)
grid_search = GridSearchCV(decision_tree, param_grid=param_grid, cv=10)
grid_search.fit(X_train, y_train)

# create and train a decision tree model with the best depth found by grid search
decision_tree = grid_search.best_estimator_

# evaluate the model's performance using 10-fold cross-validation
cv_scores = cross_val_score(decision_tree, X_train, y_train, cv=10)
print("Cross-validation scores:", cv_scores)
print("Mean cross-validation score: {:.2f}%".format(cv_scores.mean() * 100))

# make predictions on the test data
y_pred = decision_tree.predict(X_test)

# evaluate the model's performance on the test data
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
confusion = confusion_matrix(y_test, y_pred)

print("Accuracy: {:.2f}%".format(accuracy * 100))
print("Precision: {:.2f}%".format(precision * 100))
print("Recall: {:.2f}%".format(recall * 100))
print("F1 Score: {:.2f}%".format(f1 * 100))
print("Confusion Matrix:\n", confusion)
# Out:
# Cross-validation scores: [0.6        0.47142857 0.70714286 0.43884892 0.47482014 0.43884892
#  0.55395683 0.5323741  0.49640288 0.5971223 ]
# Mean cross-validation score: 53.11%
# Accuracy: 57.33%
# Precision: 53.57%
# Recall: 44.12%
# F1 Score: 48.39%
# Confusion Matrix:
#  [[28 13]
#  [19 15]]
